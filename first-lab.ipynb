# %% [markdown]
# # Project SynthLab
#
# **Objetivo Principal**: Criar uma plataforma de pesquisa de mercado e UX baseada em pessoas sintéticas (Synths) capazes de emular comportamento humano complexo.

# %% [markdown]
# ## Gerar Synths Realistas
#
# Os synths deve ser gerados atavés de um script que crie um JSON com atributos:
#
# ### Atributos Básicos
# ex: id, nome, arquetipo, descrição, link photo, data de criação.
# #### demográficos
# ex: Idade, Gênero Biológico, Identidade de gênero, Localização (País/Estado/Cidade), Escolaridade, Renda Mensal, Ocupação, Estado Civil, Composição Familiar.
# #### psicográficos
# ex: Personalidade (Big Five), Valores, Interesses, Hobbies, Estilo de Vida, Atitudes, Motivações, Inclinação Política e Religiosa.
# #### comportamentais realistas
# ex: Hábitos de Consumo, Uso de Tecnologia, Padrões de Mídia, Fonte de Notícias, Comportamento de Compra, Lealdade à Marca, Engajamento em Redes Sociais.
# #### limitações físicas e cognitivas
# ex: Deficiências Visuais, Auditivas, Motoras, Cognitivas; N
# #### capacidades tecnológicas
# ex: Nível de Alfabetização Digital, Dispositivos Utilizados (novo, antigo), Zoom de fontes e Tela, velocidade de digitação, Frequência de Uso da Internet, Familiaridade com Aplicativos e Plataformas Online.
# #### Lentes Comportamentais (Economia Comportamental)
# ex: Aversão à Perda, Desconto Hiperbólico, Efeito Chamariz, Efeito de Ancoragem, Viés de Confirmação, Status Quo (Default Bias), Sobrecarga de Informação.
#
# ### Baseados em dados reais (IBGE, pesquisas de mercado, etc.)
# Deve Garantir representação de diferentes grupos étnicos, socioeconômicos, idades, gêneros e localizações geográficas, muito em linha com a realidade Brasileira.
#
# ### Ferramentas Sugeridas
# - Python para geração de dados
# - Bibliotecas como Faker, NumPy, Pandas para manipulação de dados
# - Modelos de Machine Learning para simular comportamentos complexos

# %% [markdown]
# faca uma imagem que sera dividida em 9 partes iguais, sendo 3 linhas e 3 colunas, cada uma delas deve ter um avatar de um brasileiro ou brasileira que corresponde as descricoes abaixo:
#
# 1.     "descricao": "Homem de 69 anos, mecânico de veículos automotores, mora em Cuiabá, MT. Possui traços marcantes de Abertura, Conscienciosidade. etnia branco",
# 2.     "descricao": "Mulher de 31 anos, motoboy, mora em Uberlândia, MG. Possui traços marcantes de Conscienciosidade, Extroversao. . etnia pardo",
# 3.    "descricao": "Homem de 42 anos, entregador, mora em Aracaju, SE. Possui traços marcantes de Abertura, Conscienciosidade.  pardo",
# 4.     "descricao": "Homem de 42 anos, entregador, mora em Rio de Janeiro, RJ.  etnia asiatico",
# 5.     "descricao": "Mulher de 44 anos, consultor de vendas, mora em Santos, SP. Possui traços marcantes de Extroversao, Amabilidade.  etnia branco",
# 6.     "descricao": "Homem de 55 anos, babá, mora em Uberlândia, MG. Interesses: idiomas, vinhos, fitness. etnia pardo",
# 7.     "descricao": "Homem de 33 anos, faxineiro, mora em Santos, SP. Interesses: viagens, luta. etnia preto",
# 8.     "descricao": "Mulher de 78 anos, pedreiro, mora em Salvador, BA. Possui traços marcantes de Extroversao.  etnia pardo",
# 9.      "descricao": "Mulher de 29 anos, desempregado, mora em Recife, PE. Possui traços marcantes de Conscienciosidade.  etnia branco",
#
# em cada 1 dos 9 blocos escolha , com igual probabilidade:
# não usar filtro, usar filtor B&W, usar filtro sépia, usar filtro warm, usar filtro cold, estilo 3d movie caracter,
#
# em cada um dos 9 espaços, faá diferentes fundos, de acordo com a profissao da pessoa, preferencialmente imagens levemente desfocadas (boketh),
# as cores e estampas de roupa, acessórios (oculos, brincos, coisas no cabelo, etc), uma ou outra vez pode ter algo relacionado com a profissão

# %% [markdown]
# Sabendo que eu tenho a seguinte estrutura de dados:
#
# {
#   "$schema": "https://json-schema.org/draft/2020-12/schema",
#   "$id": "https://synthlab.com/schemas/synth/v1.0.0",
#   "title": "Synth (Synthetic Persona)",
#   "description": "Schema completo para persona sintética brasileira com atributos demográficos, psicográficos, comportamentais e cognitivos baseados em distribuições reais do IBGE Censo 2022, PNAD 2023, PNS 2019 e pesquisas verificadas",
#   "type": "object",
#   "properties": {
#     "id": {
#       "type": "string",
#       "pattern": "^[a-zA-Z0-9]{6}$",
#       "description": "Identificador único de 6 caracteres alfanuméricos"
#     },
#     "nome": {
#       "type": "string",
#       "description": "Nome completo brasileiro"
#     },
#     "arquetipo": {
#       "type": "string",
#       "description": "Resumo do perfil: {Faixa Etária} {Região} {Perfil Psicográfico}"
#     },
#     "descricao": {
#       "type": "string",
#       "description": "Descrição textual resumida do Synth"
#     },
#     "link_photo": {
#       "type": "string",
#       "format": "uri",
#       "description": "URL para foto de perfil (avatar)"
#     },
#     "created_at": {
#       "type": "string",
#       "format": "date-time",
#       "description": "Timestamp de criação em ISO 8601 com timezone"
#     },
#     "version": {
#       "type": "string",
#       "pattern": "^\\d+\\.\\d+\\.\\d+$",
#       "description": "Versão do schema (semantic versioning)"
#     },
#     "demografia": {
#       "type": "object",
#       "properties": {
#         "idade": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 120,
#           "description": "Idade em anos completos"
#         },
#         "genero_biologico": {
#           "type": "string",
#           "enum": ["masculino", "feminino", "intersexo"],
#           "description": "Gênero biológico"
#         },
#         "identidade_genero": {
#           "type": "string",
#           "enum": [
#             "homem cis",
#             "mulher cis",
#             "homem trans",
#             "mulher trans",
#             "não-binário",
#             "outro"
#           ],
#           "description": "Identidade de gênero autodeclarada"
#         },
#         "raca_etnia": {
#           "type": "string",
#           "enum": ["branco", "pardo", "preto", "amarelo", "indígena"],
#           "description": "Raça/etnia conforme categorização IBGE"
#         },
#         "localizacao": {
#           "type": "object",
#           "properties": {
#             "pais": {
#               "type": "string",
#               "const": "Brasil",
#               "description": "País (sempre Brasil nesta versão)"
#             },
#             "regiao": {
#               "type": "string",
#               "enum": ["Norte", "Nordeste", "Centro-Oeste", "Sudeste", "Sul"],
#               "description": "Região brasileira"
#             },
#             "estado": {
#               "type": "string",
#               "enum": [
#                 "AC", "AL", "AP", "AM", "BA", "CE", "DF", "ES", "GO", "MA",
#                 "MT", "MS", "MG", "PA", "PB", "PR", "PE", "PI", "RJ", "RN",
#                 "RS", "RO", "RR", "SC", "SP", "SE", "TO"
#               ],
#               "description": "Unidade Federativa (UF)"
#             },
#             "cidade": {
#               "type": "string",
#               "description": "Nome da cidade"
#             }
#           }
#         },
#         "escolaridade": {
#           "type": "string",
#           "enum": [
#             "Sem instrução",
#             "Fundamental incompleto",
#             "Fundamental completo",
#             "Médio incompleto",
#             "Médio completo",
#             "Superior incompleto",
#             "Superior completo",
#             "Pós-graduação"
#           ],
#           "description": "Nível de escolaridade conforme IBGE"
#         },
#         "renda_mensal": {
#           "type": "number",
#           "minimum": 0,
#           "description": "Renda mensal individual em BRL"
#         },
#         "ocupacao": {
#           "type": "string",
#           "description": "Profissão/ocupação conforme CBO"
#         },
#         "estado_civil": {
#           "type": "string",
#           "enum": ["solteiro", "casado", "união estável", "divorciado", "viúvo"],
#           "description": "Estado civil"
#         },
#         "composicao_familiar": {
#           "type": "object",
#           "properties": {
#             "tipo": {
#               "type": "string",
#               "enum": [
#                 "unipessoal",
#                 "casal sem filhos",
#                 "casal com filhos",
#                 "monoparental",
#                 "multigeracional",
#                 "outros"
#               ],
#               "description": "Tipo de composição familiar"
#             },
#             "numero_pessoas": {
#               "type": "integer",
#               "minimum": 1,
#               "maximum": 15,
#               "description": "Número de pessoas no domicílio"
#             }
#           }
#         }
#       }
#     },
#     "psicografia": {
#       "type": "object",
#       "properties": {
#         "personalidade_big_five": {
#           "type": "object",
#           "properties": {
#             "abertura": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Abertura a experiências (0=baixa, 100=alta)"
#             },
#             "conscienciosidade": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Conscienciosidade (0=baixa, 100=alta)"
#             },
#             "extroversao": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Extroversão (0=introvertido, 100=extrovertido)"
#             },
#             "amabilidade": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Amabilidade (0=baixa, 100=alta)"
#             },
#             "neuroticismo": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Neuroticismo (0=estável, 100=neurótico)"
#             }
#           }
#         },
#         "valores": {
#           "type": "array",
#           "items": {"type": "string"},
#           "uniqueItems": true,
#           "description": "Valores pessoais importantes - exatamente 3 valores (baseado em Schwartz Theory of Basic Values - lista curada de ~30-50 valores universais)"
#         },
#         "interesses": {
#           "type": "array",
#           "items": {"type": "string"},
#           "uniqueItems": true,
#           "description": "Áreas de interesse (1-4 itens, correlacionado com trait de abertura: baixa=1-2, média=2-3, alta=3-4)"
#         },
#         "hobbies": {
#           "type": "array",
#           "items": {"type": "string"},
#           "uniqueItems": true,
#           "description": "Hobbies praticados (fonte: Pesquisa TIM + USP sobre atividades de lazer - lista curada de ~50-80 hobbies)"
#         },
#         "estilo_vida": {
#           "type": "string",
#           "description": "Descrição do estilo de vida (CAMPO DERIVADO automaticamente dos traços Big Five)"
#         },
#         "inclinacao_politica": {
#           "type": "integer",
#           "minimum": -100,
#           "maximum": 100,
#           "description": "Espectro político (-100=esquerda, 0=centro, +100=direita). Fonte: DataSenado/Nexus Panorama Político 2024 - 29% direita, 15% esquerda, 11% centro, 40% neutro"
#         },
#         "inclinacao_religiosa": {
#           "type": "string",
#           "enum": [
#             "católico",
#             "evangélico",
#             "espírita",
#             "umbanda/candomblé",
#             "ateu/agnóstico",
#             "outras"
#           ],
#           "description": "Religião ou crença (Fonte: IBGE Censo 2022 - 56.7% católicos, 26.9% evangélicos, 9.3% sem religião)"
#         }
#       }
#     },
#     "comportamento": {
#       "type": "object",
#       "properties": {
#         "habitos_consumo": {
#           "type": "object",
#           "properties": {
#             "frequencia_compras": {
#               "type": "string",
#               "enum": ["diária", "semanal", "quinzenal", "mensal", "esporádica"],
#               "description": "Frequência de compras"
#             },
#             "preferencia_canal": {
#               "type": "string",
#               "enum": ["loja física", "e-commerce", "híbrido"],
#               "description": "Canal de compra preferido"
#             },
#             "categorias_preferidas": {
#               "type": "array",
#               "items": {"type": "string"},
#               "uniqueItems": true,
#               "description": "Categorias de produtos preferidas"
#             }
#           }
#         },
#         "uso_tecnologia": {
#           "type": "object",
#           "properties": {
#             "smartphone": {"type": "boolean"},
#             "computador": {"type": "boolean"},
#             "tablet": {"type": "boolean"},
#             "smartwatch": {"type": "boolean"}
#           }
#         },
#         "padroes_midia": {
#           "type": "object",
#           "properties": {
#             "tv_aberta": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 70,
#               "description": "Horas/semana de TV aberta"
#             },
#             "streaming": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 70,
#               "description": "Horas/semana de streaming"
#             },
#             "redes_sociais": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 70,
#               "description": "Horas/semana em redes sociais"
#             }
#           }
#         },
#         "fonte_noticias": {
#           "type": "array",
#           "items": {"type": "string"},
#           "uniqueItems": true,
#           "description": "Fontes de notícias utilizadas"
#         },
#         "comportamento_compra": {
#           "type": "object",
#           "properties": {
#             "impulsivo": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Tendência a compras impulsivas"
#             },
#             "pesquisa_antes_comprar": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Pesquisa antes de comprar"
#             }
#           }
#         },
#         "lealdade_marca": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Lealdade a marcas (0=troca fácil, 100=muito fiel)"
#         },
#         "engajamento_redes_sociais": {
#           "type": "object",
#           "properties": {
#             "plataformas": {
#               "type": "array",
#               "items": {"type": "string"},
#               "uniqueItems": true,
#               "description": "Plataformas de redes sociais usadas"
#             },
#             "frequencia_posts": {
#               "type": "string",
#               "enum": ["nunca", "raro", "ocasional", "frequente", "muito frequente"],
#               "description": "Frequência de posts"
#             }
#           }
#         }
#       }
#     },
#     "deficiencias": {
#       "type": "object",
#       "properties": {
#         "visual": {
#           "type": "object",
#           "properties": {
#             "tipo": {
#               "type": "string",
#               "enum": ["nenhuma", "leve", "moderada", "severa", "cegueira"],
#               "description": "Tipo de deficiência visual (Prevalência: 3.4% da população - IBGE PNS 2019)"
#             }
#           }
#         },
#         "auditiva": {
#           "type": "object",
#           "properties": {
#             "tipo": {
#               "type": "string",
#               "enum": ["nenhuma", "leve", "moderada", "severa", "surdez"],
#               "description": "Tipo de deficiência auditiva (Prevalência: 1.1% da população - IBGE PNS 2019)"
#             }
#           }
#         },
#         "motora": {
#           "type": "object",
#           "properties": {
#             "tipo": {
#               "type": "string",
#               "enum": ["nenhuma", "leve", "moderada", "severa"],
#               "description": "Tipo de deficiência motora de membros inferiores (Prevalência: 3.8% da população - IBGE PNS 2019)"
#             },
#             "usa_cadeira_rodas": {
#               "type": "boolean",
#               "description": "Usa cadeira de rodas (tipicamente quando deficiência motora é severa)"
#             }
#           }
#         },
#         "cognitiva": {
#           "type": "object",
#           "properties": {
#             "tipo": {
#               "type": "string",
#               "enum": ["nenhuma", "leve", "moderada", "severa"],
#               "description": "Tipo de limitação cognitiva/mental (Prevalência: 1.2% da população - IBGE PNS 2019)"
#             }
#           }
#         }
#       }
#     },
#     "capacidades_tecnologicas": {
#       "type": "object",
#       "properties": {
#         "alfabetizacao_digital": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Nível de alfabetização digital"
#         },
#         "dispositivos": {
#           "type": "object",
#           "properties": {
#             "principal": {
#               "type": "string",
#               "enum": ["smartphone", "computador", "tablet", "nenhum"],
#               "description": "Dispositivo principal"
#             },
#             "qualidade": {
#               "type": "string",
#               "enum": ["novo", "intermediário", "antigo"],
#               "description": "Qualidade do dispositivo"
#             }
#           }
#         },
#         "preferencias_acessibilidade": {
#           "type": "object",
#           "properties": {
#             "zoom_fonte": {
#               "type": "integer",
#               "minimum": 100,
#               "maximum": 300,
#               "description": "Nível de zoom/fonte em porcentagem"
#             },
#             "alto_contraste": {
#               "type": "boolean",
#               "description": "Usa modo de alto contraste"
#             }
#           }
#         },
#         "velocidade_digitacao": {
#           "type": "integer",
#           "minimum": 10,
#           "maximum": 120,
#           "description": "Velocidade de digitação em palavras por minuto"
#         },
#         "frequencia_internet": {
#           "type": "string",
#           "enum": ["diária", "semanal", "mensal", "rara"],
#           "description": "Frequência de acesso à internet"
#         },
#         "familiaridade_plataformas": {
#           "type": "object",
#           "properties": {
#             "e_commerce": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Familiaridade com e-commerce"
#             },
#             "banco_digital": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Familiaridade com banco digital"
#             },
#             "redes_sociais": {
#               "type": "integer",
#               "minimum": 0,
#               "maximum": 100,
#               "description": "Familiaridade com redes sociais"
#             }
#           }
#         }
#       }
#     },
#     "vieses": {
#       "type": "object",
#       "properties": {
#         "aversao_perda": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Intensidade de aversão à perda"
#         },
#         "desconto_hiperbolico": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Intensidade de desconto hiperbólico (preferência por recompensas imediatas)"
#         },
#         "suscetibilidade_chamariz": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Suscetibilidade ao efeito chamariz (decoy effect)"
#         },
#         "ancoragem": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Intensidade de ancoragem (influência do primeiro valor apresentado)"
#         },
#         "vies_confirmacao": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Intensidade do viés de confirmação"
#         },
#         "vies_status_quo": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Intensidade do viés de status quo (preferência por manter escolhas atuais)"
#         },
#         "sobrecarga_informacao": {
#           "type": "integer",
#           "minimum": 0,
#           "maximum": 100,
#           "description": "Suscetibilidade à sobrecarga de informação (paralisia por excesso de opções)"
#         }
#       }
#     }
#   }
# }
#
# ---
#
# Descubra na seguinte pergunta abaixo, se existe um (ou mais) parametro de filtragem dos dados e, caso exista, escreva uma operação lógica (a ser colocada na clausula WHERE de um duckdb que irá filtrar os dados da estrutura acima).
#
# Alguns detalhes sobre consultas no duckdb: Além dos operadores regulares (=,>,<,between) que funcionam para elementos comuns  (string/enum, number, float, etc) e oper. true/false para boolean. Existe um tipo especial (array) que, para buscar nele, a estrutura fica assim:
# * list_contains(psicografia.interesses, 'futebol') -- contem um
# * list_contains(psicografia.interesses, 'futebol') AND list_contains(psicografia.interesses, 'tecnologia') -- contem TODOS
# * list_intersect(psicografia.interesses,['futebol', 'tecnologia']
# ) IS NOT NULL -- contem ALGUM
#
# Veja um exemplo
#
# <INPUT>
# vamos fazer uma pesquisa de opinião sobre aplicacões financeiras.
# essas aplicação são destinadas para pessoas acima de 40 anos que usem tablets e que gostem de futebol.
# </INPUT>
# <UNDERSTANDING>
# devemos pegar apenas pessoas que tem mais de 40 anos
# E apenas pessoas que tem um comportamente de usar tablet. Não existe um campo de 'gostar de', mas entendo que interesses pode indicar isso, então, devemos pegar apenas que tem futebol entre seus interesses
# </UNDERSTANDING>
# <FILTER>
# "demografia.idade > 40
# AND comportamento.uso_tecnologia.tablet = TRUE
# AND list_contains(psicografia.interesses, 'futebol')"
# </FILTER>
